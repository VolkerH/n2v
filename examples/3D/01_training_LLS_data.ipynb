# %% [markdown]
# # Noise2Void - 3D Example

# %%
# We import all our dependencies.
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile
# Out:
# Using TensorFlow backend.
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Sample image folder

# %%
input_folder = "C:/Users/vhil0002/Documents/Senthil/cell06/Stacks/cell06"

# %% [markdown]
# # Training Data Preparation
# For training we will load __one__ low-SNR 3D-tif-volume and use the <code>N2V_DataGenerator</code> to extract non-overlapping 3D-patches. Since N2V is a self-supervised method, we don't need targets.

# %%
# We create our DataGenerator-object.
# It will help us load data and extract patches for training and validation.
datagen = N2V_DataGenerator()

# %%
# We will load all the '.tif' files from the 'data' directory. In our case it is only one.
# The function will return a list of images (numpy arrays).
# In the 'dims' parameter we specify the order of dimensions in the image files we are reading.
imgs = datagen.load_imgs_from_directory(directory = input_folder, dims='ZYX')

# Let's look at the shape of the image
print(imgs[0].shape)
# The function automatically added two extra dimension to the images:
# One at the front is used to hold a potential stack of images such as a movie.
# One at the end could hold color channels such as RGB.
# Out:
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# ...
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# TiffTag 32781: coercing invalid ASCII to bytes
# (1, 50, 608, 400, 1)

# %%
type(imgs[10])
# Out:
# numpy.ndarray

# %%
# Let's look at a maximum projection of the volume.
# We have to remove the added extra dimensions to display it.
plt.figure(figsize=(32,16))
plt.imshow(np.max(imgs[0][0,...,0],axis=0), 
           cmap='magma',
           vmin=np.percentile(imgs[0],0.1),
           vmax=np.percentile(imgs[0],99.9)
          )
plt.show()

# %%
# Here we extract patches for training and validation.
patch_shape = (32, 64, 64)
patches = datagen.generate_patches_from_list(imgs[:3], shape=patch_shape)
# Out:
# Generated patches: (432, 32, 64, 64, 1)
# Generated patches: (432, 32, 64, 64, 1)
# Generated patches: (432, 32, 64, 64, 1)

# %%
len(patches)
# Out:
# 1296

# %%
# Patches are created so they do not overlap.
# (Note: this is not the case if you specify a number of patches. See the docstring for details!)
# Non-overlapping patches enable us to split them into a training and validation set.
X = patches[:1000]
X_val = patches[1000:]

# %%
# Let's look at two patches.
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.imshow(X[0,16,...,0],cmap='magma')
plt.title('Training Patch');
plt.subplot(1,2,2)
plt.imshow(X_val[0,16,...,0],cmap='magma')
plt.title('Validation Patch');

# %% [markdown]
# ## Configure
# Noise2Void comes with a special config-object, where we store network-architecture and training specific parameters. See the docstring of the <code>N2VConfig</code> constructor for a description of all parameters.
#
# When creating the config-object, we provide the training data <code>X</code>. From <code>X</code> we extract <code>mean</code> and <code>std</code> that will be used to normalize all data before it is processed by the network. We also extract the dimensionality and number of channels from <code>X</code>.
#
# Compared to supervised training (i.e. traditional CARE), we recommend to use N2V with an increased <code>train_batch_size</code> and <code>batch_norm</code>.
# To keep the network from learning the identity we have to manipulate the input pixels during training. For this we have the parameter <code>n2v_manipulator</code> with default value <code>'uniform_withCP'</code>. Most pixel manipulators will compute the replacement value based on a neighborhood. With <code>n2v_neighborhood_radius</code> we can control its size.
#
# Other pixel manipulators:
# * normal_withoutCP: samples the neighborhood according to a normal gaussian distribution, but without the center pixel
# * normal_additive: adds a random number to the original pixel value. The random number is sampled from a gaussian distribution with zero-mean and sigma = <code>n2v_neighborhood_radius</code>
# * normal_fitted: uses a random value from a gaussian normal distribution with mean equal to the mean of the neighborhood and standard deviation equal to the standard deviation of the neighborhood.
# * identity: performs no pixel manipulation
#
# For faster training multiple pixels per input patch can be manipulated. In our experiments we manipulated about 0.198% of the input pixels per patch. For a patch size of 64 by 64 pixels this corresponds to about 8 pixels. This fraction can be tuned via <code>n2v_perc_pix</code>.
#
# For Noise2Void training it is possible to pass arbitrarily large patches to the training method. From these patches random subpatches of size <code>n2v_patch_shape</code> are extracted during training. Default patch shape is set to (64, 64), but since this is an 3D example we obviously need to specify a triple, here (32, 64, 64).
#
# In the past we experienced bleedthrough artifacts between channels if training was terminated to early. To counter bleedthrough we added the `single_net_per_channel` option, which is turned on by default. In the back a single U-Net for each channel is created and trained independently, thereby removing the possiblity of bleedthrough. <br/>
# __Note:__ Essentially the network gets multiplied by the number of channels, which increases the memory requirements. If your GPU gets too small, you can always split the channels manually and train a network for each channel one after another.

# %% [markdown]
# <font color='red'>Warning:</font> to make this example notebook execute faster, we have set <code>train_epochs</code> to only 20. <br>For better results we suggest 100 to 200 <code>train_epochs</code>.

# %%
# You can increase "train_steps_per_epoch" to get even better results at the price of longer computation. 
config = N2VConfig(X, unet_kern_size=3, 
                   train_steps_per_epoch=int(X.shape[0]/128),train_epochs=100, train_loss='mse', batch_norm=True, 
                   train_batch_size=4, n2v_perc_pix=0.198, n2v_patch_shape=(32, 64, 64), 
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'means': ['99.78623'],
#  'stds': ['3.6729314'],
#  'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'unet_residual': False,
#  'unet_n_depth': 2,
#  'unet_kern_size': 3,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, None, 1),
#  'train_loss': 'mse',
#  'train_epochs': 100,
#  'train_steps_per_epoch': 7,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 4,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 0.198,
#  'n2v_patch_shape': (32, 64, 64),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5,
#  'single_net_per_channel': True,
#  'structN2Vmask': None,
#  'probabilistic': False}

# %%
# a name used to identify the model
model_name = 'n2v_3D_lls'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config=config, name=model_name, basedir=basedir)
# Out:
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.

# %% [markdown]
# ## Training

# %%
history = model.train(X, X_val)
# Out:
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# 259 blind-spots will be generated per training patch of size (32, 64, 64).
# Preparing validation data: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 296/296 [00:00<00:00, 1232.13it/s]
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\csbdeep\utils\tf.py:245: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\csbdeep\utils\tf.py:273: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\csbdeep\utils\tf.py:280: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 7/7 [==============================] - 16s 2s/step - loss: 2.3930 - n2v_mse: 2.3930 - n2v_abs: 1.0818 - val_loss: 4.1302 - val_n2v_mse: 4.1302 - val_n2v_abs: 1.2622
# Epoch 2/100
# 7/7 [==============================] - 11s 2s/step - loss: 2.0662 - n2v_mse: 2.0662 - n2v_abs: 1.1222 - val_loss: 1.7086 - val_n2v_mse: 1.7086 - val_n2v_abs: 0.9548
# Epoch 3/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.7276 - n2v_mse: 1.7276 - n2v_abs: 1.0034 - val_loss: 8.2280 - val_n2v_mse: 8.2280 - val_n2v_abs: 1.4834
# Epoch 4/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.4826 - n2v_mse: 1.4826 - n2v_abs: 0.9178 - val_loss: 4.0964 - val_n2v_mse: 4.0964 - val_n2v_abs: 1.2087
# Epoch 5/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.6226 - n2v_mse: 1.6226 - n2v_abs: 0.9923 - val_loss: 1.7070 - val_n2v_mse: 1.7070 - val_n2v_abs: 0.9175
# Epoch 6/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.4154 - n2v_mse: 1.4154 - n2v_abs: 0.8669 - val_loss: 7.9970 - val_n2v_mse: 7.9970 - val_n2v_abs: 1.3912
# Epoch 7/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2126 - n2v_mse: 1.2126 - n2v_abs: 0.8264 - val_loss: 29.9685 - val_n2v_mse: 29.9685 - val_n2v_abs: 2.2290
# Epoch 8/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1017 - n2v_mse: 1.1017 - n2v_abs: 0.7744 - val_loss: 19.0353 - val_n2v_mse: 19.0353 - val_n2v_abs: 1.7809
# Epoch 9/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.3881 - n2v_mse: 1.3881 - n2v_abs: 0.8104 - val_loss: 11.6645 - val_n2v_mse: 11.6645 - val_n2v_abs: 1.4705
# Epoch 10/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2894 - n2v_mse: 1.2894 - n2v_abs: 0.8238 - val_loss: 7.1339 - val_n2v_mse: 7.1339 - val_n2v_abs: 1.2618
# Epoch 11/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1073 - n2v_mse: 1.1073 - n2v_abs: 0.7631 - val_loss: 2.1966 - val_n2v_mse: 2.1966 - val_n2v_abs: 0.9113
# Epoch 12/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1277 - n2v_mse: 1.1277 - n2v_abs: 0.7767 - val_loss: 1.8579 - val_n2v_mse: 1.8579 - val_n2v_abs: 0.8807
# Epoch 13/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0407 - n2v_mse: 1.0407 - n2v_abs: 0.7162 - val_loss: 7.2476 - val_n2v_mse: 7.2476 - val_n2v_abs: 1.2647
# Epoch 14/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8684 - n2v_mse: 0.8684 - n2v_abs: 0.6901 - val_loss: 8.1745 - val_n2v_mse: 8.1745 - val_n2v_abs: 1.3113
# Epoch 15/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1204 - n2v_mse: 1.1204 - n2v_abs: 0.7353 - val_loss: 1.7225 - val_n2v_mse: 1.7225 - val_n2v_abs: 0.8405
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 16/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2970 - n2v_mse: 1.2970 - n2v_abs: 0.7869 - val_loss: 1.9729 - val_n2v_mse: 1.9729 - val_n2v_abs: 0.8678
# Epoch 17/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8962 - n2v_mse: 0.8962 - n2v_abs: 0.6952 - val_loss: 1.3967 - val_n2v_mse: 1.3967 - val_n2v_abs: 0.7915
# Epoch 18/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8340 - n2v_mse: 0.8340 - n2v_abs: 0.6753 - val_loss: 1.1313 - val_n2v_mse: 1.1313 - val_n2v_abs: 0.7459
# Epoch 19/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8570 - n2v_mse: 0.8570 - n2v_abs: 0.6727 - val_loss: 1.1040 - val_n2v_mse: 1.1040 - val_n2v_abs: 0.7412
# Epoch 20/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9083 - n2v_mse: 0.9083 - n2v_abs: 0.6662 - val_loss: 1.1783 - val_n2v_mse: 1.1783 - val_n2v_abs: 0.7546
# Epoch 21/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0222 - n2v_mse: 1.0222 - n2v_abs: 0.7214 - val_loss: 1.3053 - val_n2v_mse: 1.3053 - val_n2v_abs: 0.7776
# Epoch 22/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9297 - n2v_mse: 0.9297 - n2v_abs: 0.6691 - val_loss: 1.7830 - val_n2v_mse: 1.7830 - val_n2v_abs: 0.8422
# Epoch 23/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8966 - n2v_mse: 0.8966 - n2v_abs: 0.6567 - val_loss: 2.7561 - val_n2v_mse: 2.7561 - val_n2v_abs: 0.9248
# Epoch 24/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7678 - n2v_mse: 0.7678 - n2v_abs: 0.6510 - val_loss: 2.3461 - val_n2v_mse: 2.3461 - val_n2v_abs: 0.8923
# Epoch 25/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1832 - n2v_mse: 1.1832 - n2v_abs: 0.7448 - val_loss: 1.9650 - val_n2v_mse: 1.9650 - val_n2v_abs: 0.8532
# Epoch 26/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2474 - n2v_mse: 1.2474 - n2v_abs: 0.8007 - val_loss: 1.4867 - val_n2v_mse: 1.4867 - val_n2v_abs: 0.7962
# Epoch 27/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1881 - n2v_mse: 1.1881 - n2v_abs: 0.7272 - val_loss: 1.1851 - val_n2v_mse: 1.1851 - val_n2v_abs: 0.7489
# Epoch 28/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9941 - n2v_mse: 0.9941 - n2v_abs: 0.7136 - val_loss: 1.0548 - val_n2v_mse: 1.0548 - val_n2v_abs: 0.7207
# Epoch 29/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0928 - n2v_mse: 1.0928 - n2v_abs: 0.7188 - val_loss: 1.2862 - val_n2v_mse: 1.2862 - val_n2v_abs: 0.7637
# Epoch 30/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0388 - n2v_mse: 1.0388 - n2v_abs: 0.7098 - val_loss: 2.0550 - val_n2v_mse: 2.0550 - val_n2v_abs: 0.8537
# Epoch 31/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.3872 - n2v_mse: 1.3872 - n2v_abs: 0.7454 - val_loss: 2.3035 - val_n2v_mse: 2.3035 - val_n2v_abs: 0.8745
# Epoch 32/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8389 - n2v_mse: 0.8389 - n2v_abs: 0.6753 - val_loss: 1.5622 - val_n2v_mse: 1.5622 - val_n2v_abs: 0.7963
# Epoch 33/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9029 - n2v_mse: 0.9029 - n2v_abs: 0.6869 - val_loss: 1.2704 - val_n2v_mse: 1.2704 - val_n2v_abs: 0.7560
# Epoch 34/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8003 - n2v_mse: 0.8003 - n2v_abs: 0.6487 - val_loss: 1.1376 - val_n2v_mse: 1.1376 - val_n2v_abs: 0.7317
# Epoch 35/100
# 7/7 [==============================] - 12s 2s/step - loss: 0.8502 - n2v_mse: 0.8502 - n2v_abs: 0.6360 - val_loss: 1.0356 - val_n2v_mse: 1.0356 - val_n2v_abs: 0.7093
# Epoch 36/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9570 - n2v_mse: 0.9570 - n2v_abs: 0.6979 - val_loss: 0.9636 - val_n2v_mse: 0.9636 - val_n2v_abs: 0.6905
# Epoch 37/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7333 - n2v_mse: 0.7333 - n2v_abs: 0.6199 - val_loss: 0.9460 - val_n2v_mse: 0.9460 - val_n2v_abs: 0.6844
# Epoch 38/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8042 - n2v_mse: 0.8042 - n2v_abs: 0.6532 - val_loss: 1.0612 - val_n2v_mse: 1.0612 - val_n2v_abs: 0.7119
# Epoch 39/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8342 - n2v_mse: 0.8342 - n2v_abs: 0.6692 - val_loss: 1.0698 - val_n2v_mse: 1.0698 - val_n2v_abs: 0.7140
# Epoch 40/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7680 - n2v_mse: 0.7680 - n2v_abs: 0.6410 - val_loss: 1.0343 - val_n2v_mse: 1.0343 - val_n2v_abs: 0.7062
# Epoch 41/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9775 - n2v_mse: 0.9775 - n2v_abs: 0.6633 - val_loss: 0.9656 - val_n2v_mse: 0.9656 - val_n2v_abs: 0.6877
# Epoch 42/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9593 - n2v_mse: 0.9593 - n2v_abs: 0.6906 - val_loss: 0.9669 - val_n2v_mse: 0.9669 - val_n2v_abs: 0.6868
# Epoch 43/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0551 - n2v_mse: 1.0551 - n2v_abs: 0.7054 - val_loss: 0.9608 - val_n2v_mse: 0.9608 - val_n2v_abs: 0.6837
# Epoch 44/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8951 - n2v_mse: 0.8951 - n2v_abs: 0.6619 - val_loss: 0.9607 - val_n2v_mse: 0.9607 - val_n2v_abs: 0.6820
# Epoch 45/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8244 - n2v_mse: 0.8244 - n2v_abs: 0.6372 - val_loss: 0.9656 - val_n2v_mse: 0.9656 - val_n2v_abs: 0.6851
# Epoch 46/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1467 - n2v_mse: 1.1467 - n2v_abs: 0.7291 - val_loss: 0.9555 - val_n2v_mse: 0.9555 - val_n2v_abs: 0.6813
# Epoch 47/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0929 - n2v_mse: 1.0929 - n2v_abs: 0.7126 - val_loss: 0.9494 - val_n2v_mse: 0.9494 - val_n2v_abs: 0.6799
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 48/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7924 - n2v_mse: 0.7924 - n2v_abs: 0.6140 - val_loss: 0.9440 - val_n2v_mse: 0.9440 - val_n2v_abs: 0.6781
# Epoch 49/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8133 - n2v_mse: 0.8133 - n2v_abs: 0.6523 - val_loss: 0.9386 - val_n2v_mse: 0.9386 - val_n2v_abs: 0.6773
# Epoch 50/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2256 - n2v_mse: 1.2256 - n2v_abs: 0.7278 - val_loss: 0.9369 - val_n2v_mse: 0.9369 - val_n2v_abs: 0.6774
# Epoch 51/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9126 - n2v_mse: 0.9126 - n2v_abs: 0.6708 - val_loss: 0.9306 - val_n2v_mse: 0.9306 - val_n2v_abs: 0.6749
# Epoch 52/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9042 - n2v_mse: 0.9042 - n2v_abs: 0.6671 - val_loss: 0.9495 - val_n2v_mse: 0.9495 - val_n2v_abs: 0.6817
# Epoch 53/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9645 - n2v_mse: 0.9645 - n2v_abs: 0.6926 - val_loss: 0.9507 - val_n2v_mse: 0.9507 - val_n2v_abs: 0.6820
# Epoch 54/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7569 - n2v_mse: 0.7569 - n2v_abs: 0.6397 - val_loss: 0.9361 - val_n2v_mse: 0.9361 - val_n2v_abs: 0.6766
# Epoch 55/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7482 - n2v_mse: 0.7482 - n2v_abs: 0.6445 - val_loss: 0.9310 - val_n2v_mse: 0.9310 - val_n2v_abs: 0.6743
# Epoch 56/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9211 - n2v_mse: 0.9211 - n2v_abs: 0.6741 - val_loss: 0.9290 - val_n2v_mse: 0.9290 - val_n2v_abs: 0.6716
# Epoch 57/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0619 - n2v_mse: 1.0619 - n2v_abs: 0.7051 - val_loss: 0.9326 - val_n2v_mse: 0.9326 - val_n2v_abs: 0.6742
# Epoch 58/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7950 - n2v_mse: 0.7950 - n2v_abs: 0.6493 - val_loss: 0.9960 - val_n2v_mse: 0.9960 - val_n2v_abs: 0.6924
# Epoch 59/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8857 - n2v_mse: 0.8857 - n2v_abs: 0.6701 - val_loss: 1.0085 - val_n2v_mse: 1.0085 - val_n2v_abs: 0.6949
# Epoch 60/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9932 - n2v_mse: 0.9932 - n2v_abs: 0.7397 - val_loss: 0.9911 - val_n2v_mse: 0.9911 - val_n2v_abs: 0.6907
# Epoch 61/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1745 - n2v_mse: 1.1745 - n2v_abs: 0.7198 - val_loss: 0.9842 - val_n2v_mse: 0.9842 - val_n2v_abs: 0.6887
# Epoch 62/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8807 - n2v_mse: 0.8807 - n2v_abs: 0.6402 - val_loss: 0.9662 - val_n2v_mse: 0.9662 - val_n2v_abs: 0.6844
# Epoch 63/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9775 - n2v_mse: 0.9775 - n2v_abs: 0.6956 - val_loss: 0.9560 - val_n2v_mse: 0.9560 - val_n2v_abs: 0.6817
# Epoch 64/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0754 - n2v_mse: 1.0754 - n2v_abs: 0.7186 - val_loss: 0.9271 - val_n2v_mse: 0.9271 - val_n2v_abs: 0.6722
# Epoch 65/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8763 - n2v_mse: 0.8763 - n2v_abs: 0.6715 - val_loss: 0.9217 - val_n2v_mse: 0.9217 - val_n2v_abs: 0.6698
# Epoch 66/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9157 - n2v_mse: 0.9157 - n2v_abs: 0.6633 - val_loss: 0.9276 - val_n2v_mse: 0.9276 - val_n2v_abs: 0.6712
# Epoch 67/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.2242 - n2v_mse: 1.2242 - n2v_abs: 0.7690 - val_loss: 0.9353 - val_n2v_mse: 0.9353 - val_n2v_abs: 0.6735
# Epoch 68/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8868 - n2v_mse: 0.8868 - n2v_abs: 0.6828 - val_loss: 0.9406 - val_n2v_mse: 0.9406 - val_n2v_abs: 0.6751
# Epoch 69/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.6767 - n2v_mse: 0.6767 - n2v_abs: 0.6041 - val_loss: 0.9378 - val_n2v_mse: 0.9378 - val_n2v_abs: 0.6742
# Epoch 70/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8094 - n2v_mse: 0.8094 - n2v_abs: 0.6443 - val_loss: 0.9302 - val_n2v_mse: 0.9302 - val_n2v_abs: 0.6708
# Epoch 71/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9363 - n2v_mse: 0.9363 - n2v_abs: 0.6781 - val_loss: 0.9253 - val_n2v_mse: 0.9253 - val_n2v_abs: 0.6689
# Epoch 72/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8245 - n2v_mse: 0.8245 - n2v_abs: 0.6492 - val_loss: 0.9221 - val_n2v_mse: 0.9221 - val_n2v_abs: 0.6676
# Epoch 73/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9046 - n2v_mse: 0.9046 - n2v_abs: 0.6425 - val_loss: 0.9237 - val_n2v_mse: 0.9237 - val_n2v_abs: 0.6685
# Epoch 74/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8231 - n2v_mse: 0.8231 - n2v_abs: 0.6705 - val_loss: 0.9223 - val_n2v_mse: 0.9223 - val_n2v_abs: 0.6684
# Epoch 75/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9421 - n2v_mse: 0.9421 - n2v_abs: 0.7187 - val_loss: 0.9226 - val_n2v_mse: 0.9226 - val_n2v_abs: 0.6698
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 76/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9267 - n2v_mse: 0.9267 - n2v_abs: 0.6756 - val_loss: 0.9231 - val_n2v_mse: 0.9231 - val_n2v_abs: 0.6703
# Epoch 77/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0530 - n2v_mse: 1.0530 - n2v_abs: 0.7069 - val_loss: 0.9225 - val_n2v_mse: 0.9225 - val_n2v_abs: 0.6700
# Epoch 78/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9268 - n2v_mse: 0.9268 - n2v_abs: 0.6957 - val_loss: 0.9249 - val_n2v_mse: 0.9249 - val_n2v_abs: 0.6702
# Epoch 79/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8640 - n2v_mse: 0.8640 - n2v_abs: 0.6765 - val_loss: 0.9270 - val_n2v_mse: 0.9270 - val_n2v_abs: 0.6708
# Epoch 80/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9722 - n2v_mse: 0.9722 - n2v_abs: 0.7011 - val_loss: 0.9251 - val_n2v_mse: 0.9251 - val_n2v_abs: 0.6703
# Epoch 81/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9490 - n2v_mse: 0.9490 - n2v_abs: 0.7004 - val_loss: 0.9283 - val_n2v_mse: 0.9283 - val_n2v_abs: 0.6714
# Epoch 82/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7646 - n2v_mse: 0.7646 - n2v_abs: 0.6314 - val_loss: 0.9289 - val_n2v_mse: 0.9289 - val_n2v_abs: 0.6717
# Epoch 83/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8513 - n2v_mse: 0.8513 - n2v_abs: 0.6520 - val_loss: 0.9291 - val_n2v_mse: 0.9291 - val_n2v_abs: 0.6719
# Epoch 84/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.1783 - n2v_mse: 1.1783 - n2v_abs: 0.7414 - val_loss: 0.9291 - val_n2v_mse: 0.9291 - val_n2v_abs: 0.6715
# Epoch 85/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.5957 - n2v_mse: 0.5957 - n2v_abs: 0.5808 - val_loss: 0.9259 - val_n2v_mse: 0.9259 - val_n2v_abs: 0.6701
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 86/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0997 - n2v_mse: 1.0997 - n2v_abs: 0.7272 - val_loss: 0.9215 - val_n2v_mse: 0.9215 - val_n2v_abs: 0.6689
# Epoch 87/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9415 - n2v_mse: 0.9415 - n2v_abs: 0.6809 - val_loss: 0.9190 - val_n2v_mse: 0.9190 - val_n2v_abs: 0.6678
# Epoch 88/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7793 - n2v_mse: 0.7793 - n2v_abs: 0.6413 - val_loss: 0.9181 - val_n2v_mse: 0.9181 - val_n2v_abs: 0.6674
# Epoch 89/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8384 - n2v_mse: 0.8384 - n2v_abs: 0.6590 - val_loss: 0.9196 - val_n2v_mse: 0.9196 - val_n2v_abs: 0.6677
# Epoch 90/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7457 - n2v_mse: 0.7457 - n2v_abs: 0.6159 - val_loss: 0.9209 - val_n2v_mse: 0.9209 - val_n2v_abs: 0.6681
# Epoch 91/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7762 - n2v_mse: 0.7762 - n2v_abs: 0.6535 - val_loss: 0.9216 - val_n2v_mse: 0.9216 - val_n2v_abs: 0.6683
# Epoch 92/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0978 - n2v_mse: 1.0978 - n2v_abs: 0.6944 - val_loss: 0.9209 - val_n2v_mse: 0.9209 - val_n2v_abs: 0.6682
# Epoch 93/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9850 - n2v_mse: 0.9850 - n2v_abs: 0.6928 - val_loss: 0.9178 - val_n2v_mse: 0.9178 - val_n2v_abs: 0.6673
# Epoch 94/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8306 - n2v_mse: 0.8306 - n2v_abs: 0.6500 - val_loss: 0.9180 - val_n2v_mse: 0.9180 - val_n2v_abs: 0.6675
# Epoch 95/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.9230 - n2v_mse: 0.9230 - n2v_abs: 0.6747 - val_loss: 0.9175 - val_n2v_mse: 0.9175 - val_n2v_abs: 0.6674
# Epoch 96/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.7114 - n2v_mse: 0.7114 - n2v_abs: 0.6055 - val_loss: 0.9183 - val_n2v_mse: 0.9183 - val_n2v_abs: 0.6677
# Epoch 97/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8598 - n2v_mse: 0.8598 - n2v_abs: 0.6774 - val_loss: 0.9174 - val_n2v_mse: 0.9174 - val_n2v_abs: 0.6673
# Epoch 98/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8015 - n2v_mse: 0.8015 - n2v_abs: 0.6389 - val_loss: 0.9176 - val_n2v_mse: 0.9176 - val_n2v_abs: 0.6674
# Epoch 99/100
# 7/7 [==============================] - 11s 2s/step - loss: 1.0419 - n2v_mse: 1.0419 - n2v_abs: 0.7168 - val_loss: 0.9164 - val_n2v_mse: 0.9164 - val_n2v_abs: 0.6671
# Epoch 100/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.8415 - n2v_mse: 0.8415 - n2v_abs: 0.6381 - val_loss: 0.9171 - val_n2v_mse: 0.9171 - val_n2v_abs: 0.6674
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ### After training, lets plot training and validation loss.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %% [markdown]
# ## Export Model in BioImage ModelZoo Format
# See https://imagej.net/N2V#Prediction for details.

# %%
model.export_TF(name='Noise2Void', 
                description='lattice light sheet Senthil.', 
                authors=["Volker Hilsenstein"],
                test_img=X_val[0,...,0], axes='ZYX',
                patch_shape=patch_shape)
# Out:
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\n2v\models\n2v_standard.py:625: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\n2v\models\n2v_standard.py:629: The name tf.saved_model.signature_def_utils.predict_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.predict_signature_def instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\tensorflow\python\saved_model\signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\n2v\models\n2v_standard.py:630: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# WARNING:tensorflow:From c:\users\vhil0002\anaconda3\envs\n2v\lib\site-packages\n2v\models\n2v_standard.py:632: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\vhil0002\AppData\Local\Temp\2\tmp_nbot4_n\model\saved_model.pb
#
# Model exported in BioImage ModelZoo format:
# C:\Users\vhil0002\n2v\examples\3D\models\n2v_3D\export.bioimage.io.zip
